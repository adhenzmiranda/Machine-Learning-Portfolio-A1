# %% [markdown]
# # Loading Datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # Read Data

# %%
iris = load_iris()

df = pd.DataFrame(iris.data, columns=iris.feature_names)

df['species'] = iris.target

df['species'] = df['species'].map({
    0:'iris-setosa',
    1: 'iris-versicolor',
    2:'iris-virginca'
})

print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#        species
# 0  iris-setosa
# 1  iris-setosa
# 2  iris-setosa
# 3  iris-setosa
# 4  iris-setosa

# %% [markdown]
# # Pre-processing data

# %%
x = df.drop('species', axis=1)
y = df['species']

# %% [markdown]
# # Split Data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Train te KNN Classifier
#
# これわにひん後です

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# # Make Predictions (Testing the Model)

# %%
y_pred = knn.predict(x_test)

y_pred
# Out:
# array(['iris-versicolor', 'iris-setosa', 'iris-virginca',
#        'iris-versicolor', 'iris-versicolor', 'iris-setosa',
#        'iris-versicolor', 'iris-virginca', 'iris-versicolor',
#        'iris-versicolor', 'iris-virginca', 'iris-setosa', 'iris-setosa',
#        'iris-setosa', 'iris-setosa', 'iris-versicolor', 'iris-virginca',
#        'iris-versicolor', 'iris-versicolor', 'iris-virginca',
#        'iris-setosa', 'iris-virginca', 'iris-setosa', 'iris-virginca',
#        'iris-virginca', 'iris-virginca', 'iris-virginca', 'iris-virginca',
#        'iris-setosa', 'iris-setosa'], dtype=object)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='petal length (cm)', y='petal width (cm)', data=df, hue='species')

plt.show()

# %% [markdown]
# # Calculate accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy:{accuracy*100}"+'%')

report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Accuracy:100.0%
# Classification Report:
#                   precision    recall  f1-score   support
#
#     iris-setosa       1.00      1.00      1.00        10
# iris-versicolor       1.00      1.00      1.00         9
#   iris-virginca       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
